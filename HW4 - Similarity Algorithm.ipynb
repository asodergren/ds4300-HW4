# %%
##Importing libraries
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
songs = pd.read_csv("spotify-sampled.csv")

# %%
songs
# Out:
#                     track_id                            artists  \
# 0     6NhxG3vfaRVzFosetdRITN                      Years & Years
# 1     31YAROVnfQQJUcqBTS6eMA                  Mc Kadu;Dj Victor
# 2     4mjjr1EeynuE236oOWeEMK           Dhruv Ghanekar;Mame Khan
# 3     5w3XfCH3rL6oLv4Ahfp323                      Zaeden;AAKASH
# 4     6gpgkmzNuZXh5RsJflPCT5            Cleverson Silva;Marsena
# ...                      ...                                ...
# 1195  6vV37MP78Sjc6EmJnLqdcE  SHY FX;Breakage;Break;Tyler Daley
# 1196  0S6P4AuoNUStGPgKDZ791u                         Jesse Rice
# 1197  341863z079BT4EFPiSw9DP                     Regina Spektor
# 1198  2n0U2OG5d6TuW5mKx7YrC0                     Regina Spektor
# 1199  2JAUBPBVkimRLc5BGhAkfJ                     Regina Spektor
#
#                                  album_name  \
# 0                       Anímate, es viernes
# 1                          Asterix e Obelix
# 2     Mitho Laage (The Dewarists, Season 5)
# ...

# %%
##columns of dataframe that should be used in arrays
features = ['popularity', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
           'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# %%
##Developing a pairwise cosine similarity algorithm

##Convert rows into vectors and then corresponding songs into vectors
##Create vectors using numpy arrays and then compare each array to each other

similarity_scores = []
    
##Iterate over every row and convert into numpy object
for index, song in songs.itterows():
    ##Create a vector using numpy arrays
    vector = 
    song_similarity_scores = []
        
    for index2, song2 in songs.itterows():
        if song2['name'] != song['name']:
            vector2 = 
             
            similarlity_score = dot(vector, vector2)/(norm(vector)*norm(vector2))    
            
            #euclidean_distance = np.linalg.norm(vector - vector2)
            #similarity_score = 1 / (1 + euclidean_distance)                
                
            song_similarity_scores.append(similarity_score)
        
    similarity_scores.append(song_similarity_scores)

# convert the list of similarity scores to a DataFrame
similarity_scores_df = pd.DataFrame(similarity_scores)

# set the column names of the DataFrame to the song names
similarity_scores_df.columns = df['name'].tolist()

# write the DataFrame to a CSV file
similarity_scores_df.to_csv('similarity_scores.csv', index=False)    
    
        
##End goal is to create a csv file with information (artist, album, title, genre) from song1 and the same information 
##from song2 along with the similarity score for import to neo4j

##Nodes are the two songs, relationship between the two nodes

##Write query in Neo4j to find top 5 songs for Regina Spektor (query must work for all artists)
